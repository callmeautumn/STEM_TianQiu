# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Task - Plotting lines
#
# Taking inspiration from the example we saw in the lecture (code below), plot these functions.
#
# ```
# x = np.arange(10)
# y = x * 2
# plt.plot(x, y)
#
# ```
#
# 1. Can you plot a 45 degree diagonal line, starting at 0? Hint, this line has the formula y = x. [See image](http://www.developmaths.co.uk/jpeg/algebra/graphs/strLine/eg/ke.jpg)

# %%
x = np.arange(10)
y = x * 2
plt.plot(x, y)

# %% [markdown]
# 2. How about y = -x? This is a 45 degree line mirrored (top left -> bottom right). [See image](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%3Fid%3DOIP.s62DJuVZOVD6DX6jC79FaQHaHL%26pid%3DApi&f=1)

# %%
x = np.arange(10)
y = - x
plt.plot(x, y)

# %% [markdown]
# 3. How about y = x * x (x squared). This should look like an upside down curve centered around 0. [See image](https://external-content.duckduckgo.com/iu/?u=http%3A%2F%2Fjwilson.coe.uga.edu%2Femt668%2FEMAT6680.2001%2FMorris%2Femat6700%2Fquadratic.gif&f=1&nofb=1). Think about how you might provide appropriate x values to get both sides of the curve, considering previously we have not had any **negative (less than 0) values** for x?

# %%
x = np.arange(-10,10)
y = x * x
plt.plot(x, y)

# %% [markdown]
# 4. **Bonus**: How about a sine wave? This will have the function y = sin(x) Hint: check out the method [np.sin](https://numpy.org/doc/stable/reference/generated/numpy.sin.html?highlight=sin#numpy.sin). [See image](https://content.bartleby.com/tbms-images/9781305071759/Chapter-5/images/71759-5.3-90e-question-digital_image001.png).
#
# Again, you may need to consider the x values you provide here, changing the call to `np.arange()` to consider the range and the number of values you generate.
#
# **HINT**:One cycle of the sin wave is 2 * PI long

# %%
x = np.arange(-10,10,0.001)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# ### Task - Working with Tabular Data
#
# We have the code below to load in the **This is my jam** dataset we used in the lecture.
#
# There are a series of tasks to help you practise working with extracting, editting and searching **2D data** in this format.

# %%
file = open('data/thisismyjam_top25k.tsv', 'r', encoding='utf-8')
#This data uses tabs to separate each point, not the usual commas. Can you think why?
this_is_my_jam_dataset = np.loadtxt(file, delimiter = "\t",  dtype = 'O')
#Convert everything in the 5th column to an integer (number)
this_is_my_jam_dataset[:,4] = this_is_my_jam_dataset[:,4].astype(int)

# %% [markdown]
# Print the date of the 5001st song

# %%
print(this_is_my_jam_dataset[5000,3])
# Out:
# 13/06/2012

# %% [markdown]
# Print the number of likes of the 23rd song

# %%
print(this_is_my_jam_dataset[22,4])
# Out:
# 9

# %% [markdown]
# Extract the whole column that holds the artists and save it a new variable called `names`

# %%
names = this_is_my_jam_dataset[:, 1]

print(len(names))
# Out:
# 25000

# %% [markdown]
# Print the names of the all the tracks in the dataset written by The Smiths

# %%
test = this_is_my_jam_dataset[:,1] == "The Smiths"
# print(test)
smiths_songs = this_is_my_jam_dataset[test,2]
print(smiths_songs)
# Out:
# ['Unhappy Birthday' "I Started Something I Couldn't Finish"
#  'The Boy With The Thorn In His Side' 'Panic'
#  'There Is A Light That Never Goes Out' 'Stretch Out And Wait'
#  "Heaven Knows I'm Miserable Now" 'Bigmouth Strikes Again'
#  'Girlfriend in a Coma' 'Hand In Glove' 'Reel Around the Fountain'
#  'This Charming Man' 'Handsome Devil' 'Is It Really So Strange?' 'Ask'
#  'Ask' 'How Soon Is Now?' 'This Charming Man'
#  '"""""""William, It Was Really Nothing"""""""'
#  'There Is A Light That Never Goes Out'
#  'Please Please Please Let Me Get What I Want' 'Death Of A Disco Dancer'
#  'How Soon Is Now?' 'The Headmaster Ritual' 'Handsome Devil' 'London'
#  'This Charming Man' 'Hand in Glove' 'How Soon Is Now?' 'Nowhere Fast'
#  'Shoplifters of the World Unite' 'This Charming Man [New York Vocal]'
#  'There Is a Light That Never Goes Out' 'Nowhere Fast' 'This Charming Man'
#  'There Is A Light That Never Goes Out' "I Won't Share You"
#  'How Soon Is Now?' 'Sweet and Tender Hooligan' 'Ask'
#  'Death Of A Disco Dancer (2011 Remastered Version)' 'This Charming Man'
#  'There Is A Light That Never Goes Out' 'Ask'
#  '"""""""William, It Was Really Nothing"""""""' 'Sheila Take A Bow'
#  'Sheila Take A Bow' 'Panic' 'Handsome Devil' "I Know It's Over"
#  'Shoplifters Of The World Unite' 'The Headmaster Ritual'
#  'Last Night I Dreamt That Somebody Loved Me' 'Back To The Old House'
#  'Well I Wonder' 'Panic' 'The Queen Is Dead'
#  '"""""""William, It Was Really Nothing"""""""' 'Bigmouth Strikes Again'
#  'This Night Has Opened My Eyes' "I Want the One I Can't Have"
#  "Stop Me If You Think You've Heard This One Before"
#  'Reel Around The Fountain' 'Barbarism Begins at Home' 'Unloveable'
#  'Panic' 'Shoplifters Of The World Unite' "I Want The One I Can't Have"
#  'There Is A Light That Never Goes Out' 'Asleep' 'I Keep Mine Hidden'
#  'There Is A Light That Never Goes Out' 'Well I Wonder'
#  'This Charming Man' 'Asleep' 'Girlfriend In A Coma' 'Ask'
#  'Last Night I Dreamt That Somebody Loved Me'
#  '"""""""Frankly, Mr. Shankly"""""""' 'Nowhere Fast'
#  '"""""""Please, Please, Please, Let Me Get What I Want"""""""'
#  'What Difference Does It Make?' 'This Charming Man' 'How Soon Is Now?'
#  'Well I Wonder' 'Rusholme Ruffians' 'Girl Afraid' 'How Soon Is Now?'
#  "Heaven Knows I'm Miserable Now" 'Asleep'
#  'A Rush and a Push and the Land Is Ours' 'What Difference Does It Make'
#  'The Queen Is Dead' 'Still Ill' 'There Is a Light That Never Goes Out'
#  'Asleep' 'How Soon Is Now?' 'Barbarism Begins at Home'
#  "You've Got Everything Now" 'There Is A Light That Never Goes Out'
#  'Hand in Glove' 'Reel Around the Fountain' 'How Soon Is Now?'
#  'This Charming Man' "I Know It's Over" "I Know It's Over"
#  'Bigmouth Strikes Again' 'This Charming Man' 'Hand In Glove' 'Moon River'
#  'There Is A Light That Never Goes Out' 'This Charming Man'
#  'Barbarism Begins at Home' 'Paint a Vulgar Picture' 'Asleep'
#  '"""""""You Just Haven\'t Earned It Yet, Baby"""""""'
#  '"""""""You Just Haven\'t Earned It Yet, Baby"""""""' 'Still Ill'
#  'Is It Really So Strange?'
#  '"""""""You Just Haven\'t Earned It Yet, Baby"""""""' 'How Soon Is Now?'
#  'This Charming Man' 'Handsome Devil'
#  'Last Night I Dreamt That Somebody Loved Me' 'Nowhere Fast' 'Panic' 'Ask'
#  'Reel Around The Fountain' 'Ask'
#  '"""""""William, It Was Really Nothing"""""""' 'Hand In Glove'
#  'This Charming Man' 'Some Girls Are Bigger Than Others'
#  'There Is A Light That Never Goes Out' 'This Charming Man'
#  'Please Please Please Let Me Get What I Want' 'Bigmouth Strikes Again'
#  'Ask' 'How Soon Is Now?' 'How Soon Is Now?'
#  'The Boy With the Thorn in His Side' 'Cemetry Gates'
#  '"""""""William, It Was Really Nothing"""""""'
#  'The Hand That Rocks the Cradle' 'How Soon Is Now?' 'How Soon Is Now?'
#  'Handsome Devil' '"""""""Frankly, Mr. Shankly"""""""'
#  'Is It Really So Strange?' 'How Soon Is Now?']

# %% [markdown]
# Sort the collection alphabetically by song name

# %%
sorted_songs = sorted(smiths_songs)
print(sorted_songs)
# Out:
# ['"""""""Frankly, Mr. Shankly"""""""', '"""""""Frankly, Mr. Shankly"""""""', '"""""""Please, Please, Please, Let Me Get What I Want"""""""', '"""""""William, It Was Really Nothing"""""""', '"""""""William, It Was Really Nothing"""""""', '"""""""William, It Was Really Nothing"""""""', '"""""""William, It Was Really Nothing"""""""', '"""""""William, It Was Really Nothing"""""""', '"""""""You Just Haven\'t Earned It Yet, Baby"""""""', '"""""""You Just Haven\'t Earned It Yet, Baby"""""""', '"""""""You Just Haven\'t Earned It Yet, Baby"""""""', 'A Rush and a Push and the Land Is Ours', 'Ask', 'Ask', 'Ask', 'Ask', 'Ask', 'Ask', 'Ask', 'Ask', 'Asleep', 'Asleep', 'Asleep', 'Asleep', 'Asleep', 'Back To The Old House', 'Barbarism Begins at Home', 'Barbarism Begins at Home', 'Barbarism Begins at Home', 'Bigmouth Strikes Again', 'Bigmouth Strikes Again', 'Bigmouth Strikes Again', 'Bigmouth Strikes Again', 'Cemetry Gates', 'Death Of A Disco Dancer', 'Death Of A Disco Dancer (2011 Remastered Version)', 'Girl Afraid', 'Girlfriend In A Coma', 'Girlfriend in a Coma', 'Hand In Glove', 'Hand In Glove', 'Hand In Glove', 'Hand in Glove', 'Hand in Glove', 'Handsome Devil', 'Handsome Devil', 'Handsome Devil', 'Handsome Devil', 'Handsome Devil', "Heaven Knows I'm Miserable Now", "Heaven Knows I'm Miserable Now", 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'How Soon Is Now?', 'I Keep Mine Hidden', "I Know It's Over", "I Know It's Over", "I Know It's Over", "I Started Something I Couldn't Finish", "I Want The One I Can't Have", "I Want the One I Can't Have", "I Won't Share You", 'Is It Really So Strange?', 'Is It Really So Strange?', 'Is It Really So Strange?', 'Last Night I Dreamt That Somebody Loved Me', 'Last Night I Dreamt That Somebody Loved Me', 'Last Night I Dreamt That Somebody Loved Me', 'London', 'Moon River', 'Nowhere Fast', 'Nowhere Fast', 'Nowhere Fast', 'Nowhere Fast', 'Paint a Vulgar Picture', 'Panic', 'Panic', 'Panic', 'Panic', 'Panic', 'Please Please Please Let Me Get What I Want', 'Please Please Please Let Me Get What I Want', 'Reel Around The Fountain', 'Reel Around The Fountain', 'Reel Around the Fountain', 'Reel Around the Fountain', 'Rusholme Ruffians', 'Sheila Take A Bow', 'Sheila Take A Bow', 'Shoplifters Of The World Unite', 'Shoplifters Of The World Unite', 'Shoplifters of the World Unite', 'Some Girls Are Bigger Than Others', 'Still Ill', 'Still Ill', "Stop Me If You Think You've Heard This One Before", 'Stretch Out And Wait', 'Sweet and Tender Hooligan', 'The Boy With The Thorn In His Side', 'The Boy With the Thorn in His Side', 'The Hand That Rocks the Cradle', 'The Headmaster Ritual', 'The Headmaster Ritual', 'The Queen Is Dead', 'The Queen Is Dead', 'There Is A Light That Never Goes Out', 'There Is A Light That Never Goes Out', 'There Is A Light That Never Goes Out', 'There Is A Light That Never Goes Out', 'There Is A Light That Never Goes Out', 'There Is A Light That Never Goes Out', 'There Is A Light That Never Goes Out', 'There Is A Light That Never Goes Out', 'There Is A Light That Never Goes Out', 'There Is a Light That Never Goes Out', 'There Is a Light That Never Goes Out', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man', 'This Charming Man [New York Vocal]', 'This Night Has Opened My Eyes', 'Unhappy Birthday', 'Unloveable', 'Well I Wonder', 'Well I Wonder', 'Well I Wonder', 'What Difference Does It Make', 'What Difference Does It Make?', "You've Got Everything Now"]

# %% [markdown]
# Given this sorted list, print 10 last tracks

# %%
sorted_songs[-11:-1]
# Out:
# ['This Charming Man',
#  'This Charming Man [New York Vocal]',
#  'This Night Has Opened My Eyes',
#  'Unhappy Birthday',
#  'Unloveable',
#  'Well I Wonder',
#  'Well I Wonder',
#  'Well I Wonder',
#  'What Difference Does It Make',
#  'What Difference Does It Make?']

# %% [markdown]
# Given this sorted list, print the first 14 tracks

# %%
sorted_songs[0:13]
# Out:
# ['"""""""Frankly, Mr. Shankly"""""""',
#  '"""""""Frankly, Mr. Shankly"""""""',
#  '"""""""Please, Please, Please, Let Me Get What I Want"""""""',
#  '"""""""William, It Was Really Nothing"""""""',
#  '"""""""William, It Was Really Nothing"""""""',
#  '"""""""William, It Was Really Nothing"""""""',
#  '"""""""William, It Was Really Nothing"""""""',
#  '"""""""William, It Was Really Nothing"""""""',
#  '"""""""You Just Haven\'t Earned It Yet, Baby"""""""',
#  '"""""""You Just Haven\'t Earned It Yet, Baby"""""""',
#  '"""""""You Just Haven\'t Earned It Yet, Baby"""""""',
#  'A Rush and a Push and the Land Is Ours',
#  'Ask']
